# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("synthetic_health_data (1).csv")

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   object
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   object
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   object
#  7   alcohol         4000 non-null   object
#  8   family_history  4000 non-null   object
#  9   risk_level      4000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 312.6+ KB

# %%
df.isnull().sum()
# Out:
# age               0
# diet              0
# exercise_days     0
# sleep_hours       0
# stress            0
# bmi               0
# smoking           0
# alcohol           0
# family_history    0
# risk_level        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   object
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   object
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   object
#  7   alcohol         4000 non-null   object
#  8   family_history  4000 non-null   object
#  9   risk_level      4000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 312.6+ KB

# %%
df['age'].min()
# Out:
# 18

# %%
df['age'].max()
# Out:
# 80

# %%
df['diet'].value_counts()
# Out:
# diet
# Average    1987
# Poor       1216
# Good        797
# Name: count, dtype: int64

# %%
df['exercise_days'].max()
# Out:
# 7

# %%
df['sleep_hours'].min()
# Out:
# 3

# %%
df['sleep_hours'].max()
# Out:
# 12

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
categorical_col = ['diet','stress','alcohol','family_history','risk_level','smoking']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoders={}

# %%
for i in categorical_col:
    le = LabelEncoder()
    df[i] = le.fit_transform(df[i])
    encoders[i] = le

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   int64
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   int64
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   int64
#  7   alcohol         4000 non-null   int64
#  8   family_history  4000 non-null   int64
#  9   risk_level      4000 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 312.6 KB

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop("risk_level", axis=1)
y=df['risk_level']

# %%
print(x.columns)
# Out:
# Index(['age', 'diet', 'exercise_days', 'sleep_hours', 'stress', 'bmi',
#        'smoking', 'alcohol', 'family_history'],
#       dtype='object')

# %%
print(y.name)
# Out:
# risk_level

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
model = LogisticRegression()

model.fit(x_train, y_train)
# Out:
# C:\Users\bhagy\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(x_test)

# %%
acc = accuracy_score(y_test,y_pred)

# %%
print("accuracy score of you model ", acc)
# Out:
# accuracy score of you model  0.8525

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1 = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
model1.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_predict = model1.predict(x_test)

# %%
acc1 = accuracy_score(y_test,y_predict)

# %%
print("accuracy score of you model ", acc1)
# Out:
# accuracy score of you model  0.96375

# %%
 df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
model1.predict([[56,2,3,4,0,19.9,0,0,1]])
# Out:
# C:\Users\bhagy\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])
